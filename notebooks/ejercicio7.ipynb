# %%
import sys
sys.path.append("../src")

from ejercicio7 import (
    obtener_participantes,
    validar_participantes,
    sortear_amigos
)

# %%
entrada = input("Ingrese los participantes (separados por coma): ")
participantes = obtener_participantes(entrada)

# %%
if not validar_participantes(participantes):
    print("Error: debe haber al menos 3 participantes y sin nombres duplicados.")
else:
    asignados = sortear_amigos(participantes)

    print("Sorteo de amigo invisible:")
    
    for i in range(len(participantes)):
        print(f"{participantes[i]} → {asignados[i]}")
