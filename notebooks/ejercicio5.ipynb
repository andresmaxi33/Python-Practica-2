# %%
import sys
sys.path.append("../src")

from ejercicio5 import calcular_envio

# %%
peso = float(input("Ingrese el peso del paquete (kg): "))
zona = input("Ingrese la zona de destino (local/regional/nacional): ").lower()

# %%
costo = calcular_envio(peso, zona)

if costo is None:
    print("Zona no valida. Las zonas disponibles son: local, regional, nacional.")
else:
    print(f"Costo de envio: ${costo}")
