# %%
import sys
sys.path.append("../src")
from ejercicio4 import validar_email

# %%
email = input("Ingrese un email: ")

# %%
if validar_email(email):
    print("El email es válido.")
else:
    print("El email no es válido.")
